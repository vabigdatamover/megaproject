# %% [markdown]
# # Earthquake_WeatherPy_Walsh_Gold
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install gmaps
#!pip install ipywidgets
#!jupyter nbextension enable --py widgetsnbextension
#!pip install citipy
#!pip install openweathermapy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys
import json
import csv
import datetime

import openweathermapy.core as owm
import os  # For getting API key from computer

# %%
import pandas as pd
import shutil, os, glob
import pymongo
from pymongo import MongoClient
import json
import schedule
import time
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
df = pd.concat(map(pd.read_csv, glob.glob('input' + '\*.csv')))
#Extract All source code
#https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe

# %%
df.head()
# Out:
#                         Date      Time  Latitude  Longitude        Type  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  Earthquake
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352  Earthquake
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972  Earthquake
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557  Earthquake
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427  Earthquake
#
#    Depth  Magnitude            ID
# 0  131.6        6.0  ISCGEM860706
# 1   80.0        5.8  ISCGEM860737
# 2   20.0        6.2  ISCGEM860762
# 3   15.0        5.8  ISCGEM860856
# 4   15.0        5.8  ISCGEM860890

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

## tried to get key from os
api_key = os.environ.get('weather_api_key')

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
## Generate random latitude and longitudes
# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# List for holding lat_lngs tuples
#lat_lng_rand = []

# Create a set of random lat and lng combinations
#lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
#lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
#lat_lng_rand = zip(lats, lngs)

## Generate cities list from random latitudes and longitudes using citipy.nearest_city
# List for holding cities
cities = []

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lng_rand:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set api for openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?"

# Create settings dictionary for key parameters
settings = {"units": "imperial", "appid": api_key}

city_name_name = ['name','clouds.all','sys.country','dt',
                  'main.humidity','coord.lat','coord.lon','main.temp_max','wind.speed']

all_in_one = []
count = 0
rec = 0
set = 1

for city in cities:

    if count == 50:
        time.sleep(1.1)
        count = 0
        rec = 0
        set+=1
    try:
        # Openweathermap API call to get current weather for a city
        current_weather_city = owm.get_current(city, **settings)
        awesome_city = current_weather_city(*city_name_name)
        count += 1
        rec += 1

        print(f"Processing Record {rec} of Set {set} | {current_weather_city['name']}.")
        all_in_one.append(awesome_city)

    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | Albany.
# Processing Record 2 of Set 1 | Vrangel.
# Processing Record 3 of Set 1 | Sioux Lookout.
# Processing Record 4 of Set 1 | Helong.
# Processing Record 5 of Set 1 | Butaritari.
# Processing Record 6 of Set 1 | Mataura.
# Processing Record 7 of Set 1 | Natal.
# Processing Record 8 of Set 1 | Kimberley.
# Processing Record 9 of Set 1 | Airai.
# Processing Record 10 of Set 1 | Mamontovo.
# Processing Record 11 of Set 1 | Itupiranga.
# Processing Record 12 of Set 1 | Shimoda.
# Processing Record 13 of Set 1 | Hilo.
# City not found. Skipping...
# Processing Record 14 of Set 1 | Provideniya.
# Processing Record 15 of Set 1 | Kloulklubed.
# City not found. Skipping...
# Processing Record 16 of Set 1 | Souillac.
# Processing Record 17 of Set 1 | Bredasdorp.
# Processing Record 18 of Set 1 | Jamestown.
# Processing Record 19 of Set 1 | Nuuk.
# Processing Record 20 of Set 1 | Bubaque.
# Processing Record 21 of Set 1 | San Vicente.
# Processing Record 22 of Set 1 | Hokitika.
# Processing Record 23 of Set 1 | Causapscal.
# Processing Record 24 of Set 1 | Sao Felix do Xingu.
# Processing Record 25 of Set 1 | Chokurdakh.
# Processing Record 26 of Set 1 | Buala.
# Processing Record 27 of Set 1 | Punta Arenas.
# Processing Record 28 of Set 1 | Yellowknife.
# Processing Record 29 of Set 1 | Victoria.
# Processing Record 30 of Set 1 | Bethel.
# Processing Record 31 of Set 1 | Jumla.
# Processing Record 32 of Set 1 | Carnarvon.
# Processing Record 33 of Set 1 | Coyah.
# Processing Record 34 of Set 1 | Lebu.
# Processing Record 35 of Set 1 | Kodiak.
# Processing Record 36 of Set 1 | Finschhafen.
# Processing Record 37 of Set 1 | Kununurra.
# Processing Record 38 of Set 1 | Acajutla.
# Processing Record 39 of Set 1 | Mayo.
# Processing Record 40 of Set 1 | Belmonte.
# Processing Record 41 of Set 1 | Kiunga.
# Processing Record 42 of Set 1 | Thompson.
# Processing Record 43 of Set 1 | Aklavik.
# Processing Record 44 of Set 1 | Dunga Bunga.
# Processing Record 45 of Set 1 | Krasnoturinsk.
# Processing Record 46 of Set 1 | Katsuura.
# Processing Record 47 of Set 1 | Usinsk.
# Processing Record 48 of Set 1 | Qaanaaq.
# Processing Record 49 of Set 1 | Bratsk.
# Processing Record 50 of Set 1 | Kapaa.
# Processing Record 1 of Set 2 | Karangampel.
# Processing Record 2 of Set 2 | Ponta do Sol.
# City not found. Skipping...
# Processing Record 3 of Set 2 | Cap Malheureux.
# Processing Record 4 of Set 2 | Hithadhoo.
# Processing Record 5 of Set 2 | Dikson.
# Processing Record 6 of Set 2 | Roebourne.
# Processing Record 7 of Set 2 | Puerto Ayora.
# City not found. Skipping...
# Processing Record 8 of Set 2 | Rikitea.
# City not found. Skipping...
# Processing Record 9 of Set 2 | Khatanga.
# Processing Record 10 of Set 2 | Necochea.
# Processing Record 11 of Set 2 | Georgetown.
# Processing Record 12 of Set 2 | Waipawa.
# Processing Record 13 of Set 2 | Barrow.
# City not found. Skipping...
# Processing Record 14 of Set 2 | Busselton.
# Processing Record 15 of Set 2 | Baherove.
# Processing Record 16 of Set 2 | Saint George.
# Processing Record 17 of Set 2 | Bela Vista.
# Processing Record 18 of Set 2 | Innisfail.
# Processing Record 19 of Set 2 | Atuona.
# City not found. Skipping...
# Processing Record 20 of Set 2 | Vila.
# City not found. Skipping...
# Processing Record 21 of Set 2 | Puerto Escondido.
# Processing Record 22 of Set 2 | Castro.
# Processing Record 23 of Set 2 | New Norfolk.
# Processing Record 24 of Set 2 | Avarua.
# Processing Record 25 of Set 2 | Ponta Delgada.
# Processing Record 26 of Set 2 | Sotouboua.
# City not found. Skipping...
# Processing Record 27 of Set 2 | Ayorou.
# Processing Record 28 of Set 2 | Sayat.
# Processing Record 29 of Set 2 | Ushuaia.
# Processing Record 30 of Set 2 | Coxim.
# City not found. Skipping...
# Processing Record 31 of Set 2 | Estelle.
# Processing Record 32 of Set 2 | Cape Town.
# Processing Record 33 of Set 2 | Huarmey.
# Processing Record 34 of Set 2 | Tiksi.
# Processing Record 35 of Set 2 | Flinders.
# Processing Record 36 of Set 2 | Pyapon.
# Processing Record 37 of Set 2 | Kaseda.
# Processing Record 38 of Set 2 | Mitu.
# Processing Record 39 of Set 2 | Lamu.
# Processing Record 40 of Set 2 | Bagan.
# Processing Record 41 of Set 2 | Casper.
# Processing Record 42 of Set 2 | Palmer.
# Processing Record 43 of Set 2 | Upernavik.
# City not found. Skipping...
# Processing Record 44 of Set 2 | Tailai.
# Processing Record 45 of Set 2 | Port Lincoln.
# Processing Record 46 of Set 2 | Bluff.
# Processing Record 47 of Set 2 | Norman Wells.
# Processing Record 48 of Set 2 | Charters Towers.
# Processing Record 49 of Set 2 | Hami.
# Processing Record 50 of Set 2 | Talnakh.
# Processing Record 1 of Set 3 | Bathsheba.
# Processing Record 2 of Set 3 | Komsomolskiy.
# Processing Record 3 of Set 3 | Jiazi.
# Processing Record 4 of Set 3 | North Bend.
# Processing Record 5 of Set 3 | Mabaruma.
# Processing Record 6 of Set 3 | Vaini.
# Processing Record 7 of Set 3 | Piney Green.
# Processing Record 8 of Set 3 | Pisco.
# Processing Record 9 of Set 3 | Silver City.
# Processing Record 10 of Set 3 | Puerto Carreno.
# Processing Record 11 of Set 3 | Hawera.
# Processing Record 12 of Set 3 | Pasighat.
# City not found. Skipping...
# Processing Record 13 of Set 3 | Luderitz.
# Processing Record 14 of Set 3 | Dongsheng.
# City not found. Skipping...
# Processing Record 15 of Set 3 | Ketchikan.
# Processing Record 16 of Set 3 | Salalah.
# Processing Record 17 of Set 3 | Faanui.
# Processing Record 18 of Set 3 | Tomatlan.
# Processing Record 19 of Set 3 | Isangel.
# Processing Record 20 of Set 3 | Husavik.
# Processing Record 21 of Set 3 | Honiara.
# Processing Record 22 of Set 3 | Hermanus.
# Processing Record 23 of Set 3 | Nouadhibou.
# Processing Record 24 of Set 3 | Upata.
# Processing Record 25 of Set 3 | Sarkand.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 3 | Port Alfred.
# Processing Record 27 of Set 3 | Lo Arado.
# Processing Record 28 of Set 3 | Fuerte Olimpo.
# City not found. Skipping...
# Processing Record 29 of Set 3 | Belyy Yar.
# Processing Record 30 of Set 3 | Hobart.
# Processing Record 31 of Set 3 | Sechura.
# Processing Record 32 of Set 3 | Port Moresby.
# Processing Record 33 of Set 3 | Jatiroto.
# Processing Record 34 of Set 3 | Basco.
# Processing Record 35 of Set 3 | Mutoko.
# Processing Record 36 of Set 3 | Leh.
# Processing Record 37 of Set 3 | Saryg-Sep.
# Processing Record 38 of Set 3 | Baykit.
# Processing Record 39 of Set 3 | Huicungo.
# Processing Record 40 of Set 3 | Arraial do Cabo.
# Processing Record 41 of Set 3 | Esperance.
# Processing Record 42 of Set 3 | Qinhuangdao.
# Processing Record 43 of Set 3 | East London.
# Processing Record 44 of Set 3 | Jaisalmer.
# Processing Record 45 of Set 3 | Iranshahr.
# Processing Record 46 of Set 3 | Lorengau.
# Processing Record 47 of Set 3 | Cabo San Lucas.
# Processing Record 48 of Set 3 | Ribeira Grande.
# Processing Record 49 of Set 3 | Rome.
# Processing Record 50 of Set 3 | Rosetta.
# Processing Record 1 of Set 4 | Dingle.
# Processing Record 2 of Set 4 | Launceston.
# City not found. Skipping...
# Processing Record 3 of Set 4 | Alakurtti.
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 4 | Margate.
# Processing Record 5 of Set 4 | Chabahar.
# Processing Record 6 of Set 4 | Labuhan.
# Processing Record 7 of Set 4 | Teruel.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 4 | Meulaboh.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 9 of Set 4 | Booue.
# City not found. Skipping...
# Processing Record 10 of Set 4 | Grand Gaube.
# Processing Record 11 of Set 4 | Matagami.
# Processing Record 12 of Set 4 | Axim.
# City not found. Skipping...
# Processing Record 13 of Set 4 | Chhatarpur.
# Processing Record 14 of Set 4 | Sawakin.
# Processing Record 15 of Set 4 | Atar.
# Processing Record 16 of Set 4 | Yumen.
# Processing Record 17 of Set 4 | Paratebueno.
# Processing Record 18 of Set 4 | Along.
# Processing Record 19 of Set 4 | Namibe.
# Processing Record 20 of Set 4 | Saskylakh.
# Processing Record 21 of Set 4 | Berlevag.
# Processing Record 22 of Set 4 | Constitucion.
# Processing Record 23 of Set 4 | Sao Joao da Barra.
# Processing Record 24 of Set 4 | Cidreira.
# Processing Record 25 of Set 4 | Saint-Augustin.
# Processing Record 26 of Set 4 | Wajima.
# City not found. Skipping...
# Processing Record 27 of Set 4 | Urdoma.
# Processing Record 28 of Set 4 | Sao Filipe.
# City not found. Skipping...
# Processing Record 29 of Set 4 | Tessalit.
# Processing Record 30 of Set 4 | Vermillion.
# Processing Record 31 of Set 4 | Haimen.
# Processing Record 32 of Set 4 | General Pico.
# Processing Record 33 of Set 4 | Atikokan.
# Processing Record 34 of Set 4 | Saint Anthony.
# Processing Record 35 of Set 4 | Mar del Plata.
# Processing Record 36 of Set 4 | Naze.
# City not found. Skipping...
# Processing Record 37 of Set 4 | Maiduguri.
# Processing Record 38 of Set 4 | Oytal.
# Processing Record 39 of Set 4 | Banda Aceh.
# Processing Record 40 of Set 4 | Vao.
# Processing Record 41 of Set 4 | Murgab.
# Processing Record 42 of Set 4 | Lavrentiya.
# Processing Record 43 of Set 4 | Henties Bay.
# Processing Record 44 of Set 4 | San Carlos de Bariloche.
# Processing Record 45 of Set 4 | Marana.
# Processing Record 46 of Set 4 | Penon Blanco.
# Processing Record 47 of Set 4 | Bilibino.
# Processing Record 48 of Set 4 | Hamilton.
# Processing Record 49 of Set 4 | Abong Mbang.
# Processing Record 50 of Set 4 | Tambun.
# Processing Record 1 of Set 5 | Ola.
# Processing Record 2 of Set 5 | Vila Franca do Campo.
# Processing Record 3 of Set 5 | Kharabali.
# Processing Record 4 of Set 5 | Gamboma.
# Processing Record 5 of Set 5 | Ilulissat.
# Processing Record 6 of Set 5 | Seoul.
# Processing Record 7 of Set 5 | Fortuna.
# Processing Record 8 of Set 5 | Nieuw Amsterdam.
# Processing Record 9 of Set 5 | Cayenne.
# Processing Record 10 of Set 5 | Abu Dhabi.
# Processing Record 11 of Set 5 | Santa Rosa.
# City not found. Skipping...
# Processing Record 12 of Set 5 | Manica.
# Processing Record 13 of Set 5 | Puri.
# Processing Record 14 of Set 5 | Saint-Philippe.
# City not found. Skipping...
# Processing Record 15 of Set 5 | Shihezi.
# City not found. Skipping...
# Processing Record 16 of Set 5 | Kutum.
# Processing Record 17 of Set 5 | Lithakia.
# Processing Record 18 of Set 5 | Port Hedland.
# Processing Record 19 of Set 5 | Vigrestad.
# Processing Record 20 of Set 5 | Fairview.
# Processing Record 21 of Set 5 | Tasiilaq.
# Processing Record 22 of Set 5 | Srednekolymsk.
# Processing Record 23 of Set 5 | Loukhi.
# Processing Record 24 of Set 5 | Ialibu.
# Processing Record 25 of Set 5 | Kaitangata.
# Processing Record 26 of Set 5 | Udachnyy.
# Processing Record 27 of Set 5 | Koubia.
# Processing Record 28 of Set 5 | Lakes Entrance.
# Processing Record 29 of Set 5 | Sfantu Gheorghe.
# City not found. Skipping...
# Processing Record 30 of Set 5 | Chuy.
# Processing Record 31 of Set 5 | Pangody.
# Processing Record 32 of Set 5 | Clyde River.
# City not found. Skipping...
# Processing Record 33 of Set 5 | Masindi.
# Processing Record 34 of Set 5 | Ambanja.
# Processing Record 35 of Set 5 | Rawson.
# Processing Record 36 of Set 5 | Ariquemes.
# Processing Record 37 of Set 5 | Geraldton.
# Processing Record 38 of Set 5 | Ostrovnoy.
# Processing Record 39 of Set 5 | Shemonaikha.
# Processing Record 40 of Set 5 | Del Rio.
# Processing Record 41 of Set 5 | Torbay.
# Processing Record 42 of Set 5 | Mahibadhoo.
# Processing Record 43 of Set 5 | Bambous Virieux.
# Processing Record 44 of Set 5 | Tuatapere.
# Processing Record 45 of Set 5 | Kruisfontein.
# Processing Record 46 of Set 5 | Port Elizabeth.
# Processing Record 47 of Set 5 | Itaituba.
# City not found. Skipping...
# Processing Record 48 of Set 5 | Broome.
# Processing Record 49 of Set 5 | Sisimiut.
# Processing Record 50 of Set 5 | Seymchan.
# Processing Record 1 of Set 6 | Pangoa.
# Processing Record 2 of Set 6 | Tautira.
# Processing Record 3 of Set 6 | Takoradi.
# Processing Record 4 of Set 6 | Le Port.
# City not found. Skipping...
# Processing Record 5 of Set 6 | Kysyl-Syr.
# Processing Record 6 of Set 6 | Zhezkazgan.
# Processing Record 7 of Set 6 | Cabedelo.
# Processing Record 8 of Set 6 | Araouane.
# Processing Record 9 of Set 6 | Gizo.
# Processing Record 10 of Set 6 | Scarborough.
# Processing Record 11 of Set 6 | Omboue.
# Processing Record 12 of Set 6 | Padang.
# Processing Record 13 of Set 6 | San Cristobal.
# Processing Record 14 of Set 6 | Paamiut.
# Processing Record 15 of Set 6 | Leningradskiy.
# Processing Record 16 of Set 6 | Shache.
# Processing Record 17 of Set 6 | Wanlaweyn.
# Processing Record 18 of Set 6 | Suhbaatar.
# Processing Record 19 of Set 6 | Harper.
# Processing Record 20 of Set 6 | Katobu.
# Processing Record 21 of Set 6 | Adrar.
# Processing Record 22 of Set 6 | Lasa.
# Processing Record 23 of Set 6 | Nanortalik.
# Processing Record 24 of Set 6 | Itoman.
# Processing Record 25 of Set 6 | Bontang.
# Processing Record 26 of Set 6 | Mount Isa.
# Processing Record 27 of Set 6 | Cherskiy.
# City not found. Skipping...
# Processing Record 28 of Set 6 | Kulu.
# Processing Record 29 of Set 6 | Tura.
# Processing Record 30 of Set 6 | Srbinovo.
# Processing Record 31 of Set 6 | Sorland.
# Processing Record 32 of Set 6 | Ribeira Brava.
# Processing Record 33 of Set 6 | Nishihara.
# Processing Record 34 of Set 6 | Tazovskiy.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 6 | Abu Samrah.
# Processing Record 36 of Set 6 | Kahului.
# Processing Record 37 of Set 6 | Betsiamites.
# Processing Record 38 of Set 6 | Namatanai.
# Processing Record 39 of Set 6 | Mahebourg.
# Processing Record 40 of Set 6 | Bimbo.
# Processing Record 41 of Set 6 | Port-Gentil.
# Processing Record 42 of Set 6 | Port Macquarie.
# Processing Record 43 of Set 6 | Elban.
# Processing Record 44 of Set 6 | Nikolskoye.
# Processing Record 45 of Set 6 | Lake City.
# Processing Record 46 of Set 6 | Pudem.
# Processing Record 47 of Set 6 | Puerto Colombia.
# City not found. Skipping...
# Processing Record 48 of Set 6 | Muhororo.
# Processing Record 49 of Set 6 | Caarapo.
# Processing Record 50 of Set 6 | Los Llanos de Aridane.
# City not found. Skipping...
# Processing Record 1 of Set 7 | Irbeyskoye.
# Processing Record 2 of Set 7 | Biskamzha.
# Processing Record 3 of Set 7 | Biak.
# Processing Record 4 of Set 7 | Bandarbeyla.
# Processing Record 5 of Set 7 | Yulara.
# Processing Record 6 of Set 7 | Tucurui.
# Processing Record 7 of Set 7 | Vredendal.
# Processing Record 8 of Set 7 | Cheney.
# Processing Record 9 of Set 7 | Vagay.
# Processing Record 10 of Set 7 | Chicama.
# City not found. Skipping...
# Processing Record 11 of Set 7 | Yeppoon.
# Processing Record 12 of Set 7 | Mehamn.
# Processing Record 13 of Set 7 | Zhigansk.
# City not found. Skipping...
# Processing Record 14 of Set 7 | Cascais.
# Processing Record 15 of Set 7 | Numan.
# Processing Record 16 of Set 7 | Severo-Kurilsk.
# Processing Record 17 of Set 7 | Portland.
# Processing Record 18 of Set 7 | Blackwater.
# Processing Record 19 of Set 7 | Laerdalsoyri.
# Processing Record 20 of Set 7 | Rehoboth.
# Processing Record 21 of Set 7 | Pacific Grove.
# Processing Record 22 of Set 7 | Poronaysk.
# Processing Record 23 of Set 7 | Kunda.
# Processing Record 24 of Set 7 | Charlestown.
# Processing Record 25 of Set 7 | Neyshabur.
# Processing Record 26 of Set 7 | Buarcos.
# Processing Record 27 of Set 7 | Kandalaksha.
# Processing Record 28 of Set 7 | Saint-Pierre.
# Processing Record 29 of Set 7 | Khakhea.
# City not found. Skipping...
# Processing Record 30 of Set 7 | Roswell.
# Processing Record 31 of Set 7 | Tateyama.
# Processing Record 32 of Set 7 | Barberton.
# Processing Record 33 of Set 7 | Rovaniemi.
# Processing Record 34 of Set 7 | Okha.
# Processing Record 35 of Set 7 | Filadelfia.
# Processing Record 36 of Set 7 | Granadilla de Abona.
# Processing Record 37 of Set 7 | Port Hardy.
# Processing Record 38 of Set 7 | Iquitos.
# Processing Record 39 of Set 7 | Waingapu.
# Processing Record 40 of Set 7 | Kanigiri.
# Processing Record 41 of Set 7 | Nago.
# Processing Record 42 of Set 7 | Ha Giang.
# Processing Record 43 of Set 7 | Kirakira.
# Processing Record 44 of Set 7 | Heihe.
# City not found. Skipping...
# Processing Record 45 of Set 7 | Camacha.
# Processing Record 46 of Set 7 | Chara.
# Processing Record 47 of Set 7 | Alofi.
# City not found. Skipping...
# Processing Record 48 of Set 7 | Pevek.
# Processing Record 49 of Set 7 | Sonoita.
# Processing Record 50 of Set 7 | Longyearbyen.
# Processing Record 1 of Set 8 | Tuktoyaktuk.
# Processing Record 2 of Set 8 | Sidney.
# Processing Record 3 of Set 8 | Lalas.
# Processing Record 4 of Set 8 | Razole.
# Processing Record 5 of Set 8 | Alice Springs.
# Processing Record 6 of Set 8 | Mount Gambier.
# Processing Record 7 of Set 8 | Lima.
# Processing Record 8 of Set 8 | Merauke.
# Processing Record 9 of Set 8 | Port Hawkesbury.
# Processing Record 10 of Set 8 | Manakara.
# Processing Record 11 of Set 8 | Dudinka.
# Processing Record 12 of Set 8 | Abaza.
# Processing Record 13 of Set 8 | Iwakuni.
# Processing Record 14 of Set 8 | Coihaique.
# Processing Record 15 of Set 8 | Bukama.
# Processing Record 16 of Set 8 | Prigorodka.
# City not found. Skipping...
# Processing Record 17 of Set 8 | Maketu.
# Processing Record 18 of Set 8 | Mirnyy.
# City not found. Skipping...
# Processing Record 19 of Set 8 | Sawtell.
# Processing Record 20 of Set 8 | Guerrero Negro.
# Processing Record 21 of Set 8 | Viedma.
# Processing Record 22 of Set 8 | Kapit.
# Processing Record 23 of Set 8 | Sistranda.
# Processing Record 24 of Set 8 | Mul.
# City not found. Skipping...
# Processing Record 25 of Set 8 | Kislyakovskaya.
# Processing Record 26 of Set 8 | Soe.
# Processing Record 27 of Set 8 | Ust-Kuyga.
# Processing Record 28 of Set 8 | Cedar City.
# Processing Record 29 of Set 8 | Balkanabat.
# Processing Record 30 of Set 8 | Luhyny.
# Processing Record 31 of Set 8 | Baghdad.
# City not found. Skipping...
# Processing Record 32 of Set 8 | San Jose.
# Processing Record 33 of Set 8 | Mossendjo.
# Processing Record 34 of Set 8 | Fort Saint James.
# Processing Record 35 of Set 8 | Darab.
# Processing Record 36 of Set 8 | Hindupur.
# Processing Record 37 of Set 8 | Lagoa.
# Processing Record 38 of Set 8 | Palu.
# Processing Record 39 of Set 8 | Hongjiang.
# Processing Record 40 of Set 8 | Los Cedrales.
# Processing Record 41 of Set 8 | Riyadh.
# Processing Record 42 of Set 8 | Loum.
# Processing Record 43 of Set 8 | Huinan.
# Processing Record 44 of Set 8 | Amapa.
# Processing Record 45 of Set 8 | Dunedin.
# Processing Record 46 of Set 8 | Goksun.
# Processing Record 47 of Set 8 | Manaus.
# Processing Record 48 of Set 8 | Bandar-e Lengeh.
# City not found. Skipping...
# Processing Record 49 of Set 8 | Acari.
# Processing Record 50 of Set 8 | Hambantota.
# Processing Record 1 of Set 9 | Madhubani.
# Processing Record 2 of Set 9 | Capaci.
# Processing Record 3 of Set 9 | Manaure.
# Processing Record 4 of Set 9 | Suicheng.
# Processing Record 5 of Set 9 | Snasa.
# Processing Record 6 of Set 9 | Port Blair.
# City not found. Skipping...
# Processing Record 7 of Set 9 | Datong.
# Processing Record 8 of Set 9 | Horsham.
# Processing Record 9 of Set 9 | Lata.
# Processing Record 10 of Set 9 | Port Arthur.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 9 | Vila Velha.
# Processing Record 12 of Set 9 | Laguna.
# Processing Record 13 of Set 9 | Vardo.
# Processing Record 14 of Set 9 | Bitkine.
# Processing Record 15 of Set 9 | Terre-de-Bas.
# City not found. Skipping...
# Processing Record 16 of Set 9 | Lethem.
# Processing Record 17 of Set 9 | Jiuquan.
# Processing Record 18 of Set 9 | Hammerfest.
# Processing Record 19 of Set 9 | Alyangula.
# Processing Record 20 of Set 9 | Yerbogachen.
# Processing Record 21 of Set 9 | Salta.
# Processing Record 22 of Set 9 | Shakiso.
# Processing Record 23 of Set 9 | Mitsamiouli.
# Processing Record 24 of Set 9 | Champasak.
# Processing Record 25 of Set 9 | Jishou.
# Processing Record 26 of Set 9 | Hasaki.
# Processing Record 27 of Set 9 | Dicabisagan.
# Processing Record 28 of Set 9 | Presidencia Roque Saenz Pena.
# Processing Record 29 of Set 9 | Warwick.
# Processing Record 30 of Set 9 | Coquimbo.
# Processing Record 31 of Set 9 | Nizwa.
# Processing Record 32 of Set 9 | Balkhash.
# Processing Record 33 of Set 9 | Knysna.
# Processing Record 34 of Set 9 | Ouahigouya.
# Processing Record 35 of Set 9 | San Quintin.
# Processing Record 36 of Set 9 | Nehe.
# Processing Record 37 of Set 9 | Portree.
# Processing Record 38 of Set 9 | Maningrida.
# Processing Record 39 of Set 9 | Inzer.
# Processing Record 40 of Set 9 | Boa Vista.
# Processing Record 41 of Set 9 | Ntchisi.
# Processing Record 42 of Set 9 | Wewak.
# Processing Record 43 of Set 9 | Biu.
# Processing Record 44 of Set 9 | Kortkeros.
# Processing Record 45 of Set 9 | Touros.
# Processing Record 46 of Set 9 | Aksay.
# Processing Record 47 of Set 9 | Ayan.
# City not found. Skipping...
# Processing Record 48 of Set 9 | Danielskuil.
# Processing Record 49 of Set 9 | Chapais.
# Processing Record 50 of Set 9 | Kavieng.
# Processing Record 1 of Set 10 | Mora.
# Processing Record 2 of Set 10 | San Patricio.
# Processing Record 3 of Set 10 | Caloundra.
# City not found. Skipping...
# Processing Record 4 of Set 10 | Fatehabad.
# Processing Record 5 of Set 10 | Iqaluit.
# Processing Record 6 of Set 10 | Paine.
# Processing Record 7 of Set 10 | Auki.
# Processing Record 8 of Set 10 | Lesozavodsk.
# Processing Record 9 of Set 10 | Muli.
# Processing Record 10 of Set 10 | Kharp.
# Processing Record 11 of Set 10 | Cacule.
# Processing Record 12 of Set 10 | Matara.
# City not found. Skipping...
# Processing Record 13 of Set 10 | Outjo.
# Processing Record 14 of Set 10 | Najran.
# Processing Record 15 of Set 10 | Mae Hong Son.
# Processing Record 16 of Set 10 | Quelimane.
# Processing Record 17 of Set 10 | Westport.
# Processing Record 18 of Set 10 | Charleston.
# Processing Record 19 of Set 10 | Praia.
# City not found. Skipping...
# Processing Record 20 of Set 10 | Maniitsoq.
# Processing Record 21 of Set 10 | Mapastepec.
# Processing Record 22 of Set 10 | Noumea.
# Processing Record 23 of Set 10 | Balaipungut.
# Processing Record 24 of Set 10 | Christchurch.
# Processing Record 25 of Set 10 | Almaznyy.
# Processing Record 26 of Set 10 | Dakar.
# Processing Record 27 of Set 10 | Gao.
# Processing Record 28 of Set 10 | Terrace.
# Processing Record 29 of Set 10 | Biltine.
# Processing Record 30 of Set 10 | Ambovombe.
# Processing Record 31 of Set 10 | Cabatuan.
# Processing Record 32 of Set 10 | Trincomalee.
# Processing Record 33 of Set 10 | Svetlogorsk.
# Processing Record 34 of Set 10 | Hualmay.
# Processing Record 35 of Set 10 | College.
# Processing Record 36 of Set 10 | Selma.
# Processing Record 37 of Set 10 | Hirara.
# Processing Record 38 of Set 10 | Lompoc.
# Processing Record 39 of Set 10 | Makanya.
# Processing Record 40 of Set 10 | Poum.
# Processing Record 41 of Set 10 | Grindavik.
# Processing Record 42 of Set 10 | Fairbanks.
# Processing Record 43 of Set 10 | Gari.
# Processing Record 44 of Set 10 | Arona.
# Processing Record 45 of Set 10 | Straumen.
# City not found. Skipping...
# Processing Record 46 of Set 10 | Bahia de Caraquez.
# Processing Record 47 of Set 10 | Saint Pete Beach.
# Processing Record 48 of Set 10 | Sayyan.
# Processing Record 49 of Set 10 | Oktyabrskoye.
# Processing Record 50 of Set 10 | Merced.
# Processing Record 1 of Set 11 | Wardha.
# Processing Record 2 of Set 11 | Vestmannaeyjar.
# Processing Record 3 of Set 11 | Shenjiamen.
# Processing Record 4 of Set 11 | Abnub.
# Processing Record 5 of Set 11 | Trelew.
# City not found. Skipping...
# Processing Record 6 of Set 11 | Yinchuan.
# Processing Record 7 of Set 11 | Windsor.
# Processing Record 8 of Set 11 | Samarai.
# Processing Record 9 of Set 11 | Yagodnoye.
# City not found. Skipping...
# Processing Record 10 of Set 11 | Bosaso.
# Processing Record 11 of Set 11 | Paraul.
# Processing Record 12 of Set 11 | Igrim.
# Processing Record 13 of Set 11 | Vilhena.
# City not found. Skipping...
# Processing Record 14 of Set 11 | Andapa.
# Processing Record 15 of Set 11 | Juneau.
# Processing Record 16 of Set 11 | Brufut.
# City not found. Skipping...
# Processing Record 17 of Set 11 | Kidal.
# Processing Record 18 of Set 11 | Goderich.
# Processing Record 19 of Set 11 | Porto Novo.
# Processing Record 20 of Set 11 | Gat.
# Processing Record 21 of Set 11 | Terney.
# Processing Record 22 of Set 11 | Tymovskoye.
# Processing Record 23 of Set 11 | Bonito.
# Processing Record 24 of Set 11 | Pavlovsk.
# Processing Record 25 of Set 11 | Muisne.
# Processing Record 26 of Set 11 | Codrington.
# Processing Record 27 of Set 11 | Bangassou.
# Processing Record 28 of Set 11 | Oktyabrskiy.
# Processing Record 29 of Set 11 | Faya.
# Processing Record 30 of Set 11 | Tchollire.
# Processing Record 31 of Set 11 | Svetlaya.
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Converting Raw Data to DataFrame
weather_data = pd.DataFrame(all_in_one,
                            columns=['City', 'Cloudiness', 'Country','Date',
                                     'Humidity','Lat','lng','Max Temp','Wind Speed'])

# Writing data to csv file
weather_data.to_csv(output_data_file, header=True, index=True, index_label= 'Index')

# %%
weather_data.count()
# Out:
# City          569
# Cloudiness    569
# Country       569
# Date          569
# Humidity      569
# Lat           569
# lng           569
# Max Temp      569
# Wind Speed    569
# dtype: int64

# %%
weather_data.head(5)
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     lng  \
# 0     Oktyabrskiy           0      RU  1566703204        87  55.61   37.97
# 1           Alofi          38      NU  1566703205        83 -19.06 -169.92
# 2          Teruel           0      ES  1566703205        87  40.34   -1.11
# 3  Ribeira Grande           5      PT  1566703205        79  38.52  -28.70
# 4         Dunedin         100      NZ  1566703042        62 -45.87  170.50
#
#    Max Temp  Wind Speed
# 0     55.00        4.47
# 1     80.60        4.70
# 2     66.20        1.12
# 3     69.51       15.35
# 4     55.00        7.00

# %%
HTML('''
        <style>
            .df tbody tr:nth-child(even) { background-color: lightblue; }
        </style>
        ''' + weather_data.to_html(classes="df"))




weather_data.to_html('latitude_data-test.html')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Max Temp', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Max Temperature (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('output_data/Lat_vs_Temp.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Humidity', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Humidity (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('output_data/Lat_vs_Humidity.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Cloudiness', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Cloudiness (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('output_data/Lat_vs_Cloudiness.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Wind Speed', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Wind Speed (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('output_data/Lat_vs_WindSpeed.png', bbox_inches="tight")

# %% [markdown]
# ### Observable trends
# * 1. The temperature is highest 20 to 40 degrees north of the equator, which is consistent with the seasonal expectation.
# * 2. Cloud coverage is consistent world-wide and across the range of latitude.
# * 3. Wind speeds show a slight peak around the equator.
